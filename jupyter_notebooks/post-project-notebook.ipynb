# %% [markdown]
# I'm going to use this new notebook to fix some things, post project submission
# I won't push this to git!! Not yet anyway, I'll wait for feedback first
#
# (Submitted on 16.10.25, updated on 08.01.26)
#
# Issues to fix:1. activating correctly using .venv\Scripts\activate.ps1 (I forgot the .ps1 before)
# -> Sorted by using the Git Bash terminal
#
# 2. update pip to newer version
# -> Sorted by running python -m pip install --upgrade pip
#
# 3. try import os package etc from the notebook template
# -> this worked fine for my Capstone project notebooks

# %% [markdown]
# Second task is to create a dashboard in Power BI to visualize the data
#
# Third task is to use Tableau to visualize the data (still new to me)

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\beth_\\Documents\\health-insurance\\health-insurance-project-1\\jupyter_notebooks'

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\beth_\\Documents\\health-insurance\\health-insurance-project-1'

# %%
# no errors yet!
# I'm looking online to try and understand the directories
